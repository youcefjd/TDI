# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.imports import *
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
PATH = "/users/youcefdjeddar/downloads/cars/"

# %%
files = os.listdir(f'{PATH}valid/ped')

# %%
img = plt.imread(f'{PATH}valid/ped/{files[5]}')

# %%
plt.imshow(img)

# %% [markdown]
# i have selected deliberately some blurred images.

# %%
img[:2,:2]
# Out:
# array([[[117, 123, 123],
#         [111, 117, 117]],
#
#        [[ 60,  66,  66],
#         [108, 114, 114]]], dtype=uint8)

# %%
img.shape
# Out:
# (445, 346, 3)

# %% [markdown]
# The shape of an image is a 3d Tensor.

# %%
files1 = os.listdir(f'{PATH}valid/left')

# %%
img1 = plt.imread(f'{PATH}valid/left/{files1[20]}')

# %%
plt.imshow(img1)

# %%
sz = 224
arch=resnet50

# %% [markdown]
# I opted for an image size of 224 - comparable to ImageNet. I also chose ResNet50 as architecture.

# %%
data = ImageClassifierData.from_paths(PATH, tfms = tfms_from_model(arch, sz))
learn = ConvLearner.pretrained(arch, data)
learn.fit(0.01, 3)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.706573   1.019262   0.685324
#     1      0.36798    1.103478   0.662847
#     2      0.22906    1.087167   0.690613
# [array([1.08717]), 0.6906126046716615]

# %% [markdown]
# Without any param tuning, the model got already a score of 70%.

# %%
learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1, style=ProgressStyle(description_width='initial…
#  89%|████████▉ | 42/47 [07:19<00:51, 10.30s/it, loss=0.542]

# %%
learn.sched.plot_lr()

# %%
learn.sched.plot()

# %%
learn.fit(0.001, 3)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=3, style=ProgressStyle(description_width='initial…
# epoch      trn_loss   val_loss   accuracy
#     0      0.139018   1.065312   0.68929
#     1      0.132373   1.062355   0.690613
#     2      0.124596   1.064711   0.692816
# [array([1.06471]), 0.6928162185985015]

# %%
tfms = tfms_from_model(resnet34, sz, aug_tfms=transforms_side_on, max_zoom=1.1)
data = ImageClassifierData.from_paths(PATH, bs = 2, tfms = tfms)
learn = ConvLearner.pretrained(arch, data)

# %% [markdown]
# Here I incorporated data augmentation. A technique that takes an image and flip it a little bit, rotate it a little bit...etc to generate new data.

# %%
learn.lr_find()
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1, style=ProgressStyle(description_width='initial…
#  57%|█████▋    | 872/1524 [04:24<03:16,  3.32it/s, loss=6.84]

# %%
learn.sched.plot_lr()

# %%
learn.unfreeze()

# %%
lr = np.array([0.0001, 0.0003, 0.001])

# %%
def get_augs():
    data = ImageClassifierData.from_paths(PATH, bs=2, tfms=tfms, num_workers=1)
    x,_ = next(iter(data.aug_dl))
    return data.trn_ds.denorm(x)[1]

# %%
ims = np.stack([get_augs() for i in range(9)])

# %%
plots(ims, rows=3)

# %% [markdown]
# Data Augmentation takes an image and 'plays' with it.
